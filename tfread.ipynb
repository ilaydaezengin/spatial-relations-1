# %%
import tensorflow as tf
import reader
# Out:
# /home/ec2-user/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ec2-user/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ec2-user/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
filenames, iterator, next_element = reader.make_dataset(batch_size=16)
# Out:
# WARNING:tensorflow:From /home/ec2-user/comp492/Text2Image-cemil-slim-dataset-reader/reader.py:128: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /home/ec2-user/comp492/Text2Image-cemil-slim-dataset-reader/reader.py:167: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /home/ec2-user/comp492/Text2Image-cemil-slim-dataset-reader/reader.py:175: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /home/ec2-user/comp492/Text2Image-cemil-slim-dataset-reader/reader.py:269: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
with tf.Session() as sess:
  # Initialize `iterator` with train data.
  training_filenames = ["/home/ec2-user/efs/slim-dataset/synthetic_data/train/wid132/0.tfrecord"]
  sess.run(iterator.initializer, feed_dict={filenames: training_filenames})

  ne_value = sess.run(next_element)

  # Initialize `iterator` with validation data.
  # validation_filenames = ["/var/data/train_1.tfrecord", ...]
  # sess.run(iterator.initializer, feed_dict={filenames: validation_filenames})

  # ne_value = sess.run(next_element)

# %%
ne_value
# Out:
# (((array([[[[[0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              ...,
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ]],
#
#             [[0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              ...,
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ]],
#
#             [[0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              ...,
#              [0.6039216 , 0.8862746 , 0.9803922 ],
#              [0.6039216 , 0.8862746 , 0.9803922 ],
# ...

# %%
next_element
# Out:
# (((<tf.Tensor 'IteratorGetNext:0' shape=(?, 9, ?, ?, ?) dtype=float32>,
#    <tf.Tensor 'IteratorGetNext:1' shape=(?, 9, 4) dtype=float32>,
#    <tf.Tensor 'IteratorGetNext:2' shape=(?, 9) dtype=string>),
#   <tf.Tensor 'IteratorGetNext:3' shape=(?, 4) dtype=float32>),
#  (<tf.Tensor 'IteratorGetNext:4' shape=(?, ?, ?, ?) dtype=float32>,
#   <tf.Tensor 'IteratorGetNext:5' shape=(?,) dtype=string>,
#   <tf.Tensor 'IteratorGetNext:6' shape=(?, ?, ?, ?) dtype=float32>),
#  {'images': <tf.Tensor 'IteratorGetNext:9' shape=(?, 10, ?, ?, ?) dtype=uint8>,
#   'cameras': <tf.Tensor 'IteratorGetNext:7' shape=(?, 10, 3) dtype=float32>,
#   'captions': <tf.Tensor 'IteratorGetNext:8' shape=(?, ?) dtype=string>,
#   'simplified_captions': <tf.Tensor 'IteratorGetNext:10' shape=(?, ?) dtype=string>,
#   'top_down': <tf.Tensor 'IteratorGetNext:11' shape=(?, ?, ?, ?) dtype=uint8>})
